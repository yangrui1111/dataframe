# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
Pop =pd.read_excel(r'http://book.flowingdata.com/ch05/data/us-population-by-age.xls')

# %%
Pop
# Out:
#                                                     Under 5  5 to 19  \
# 1860                                                   15.4     35.8
# 1870                                                   14.3     35.4
# 1880                                                   13.8     34.3
# 1890                                                   12.2     33.9
# 1900                                                   12.1     32.3
# 1910                                                   11.6     30.4
# 1920                                                   10.9     29.8
# 1930                                                    9.3     29.5
# 1940                                                    8.0     26.4
# 1950                                                   10.7     23.2
# 1960                                                   11.3     27.1
# 1970                                                    8.4     29.5
# 1980                                                    7.2     24.8
# ...

# %%
fig,ax=plt.subplots(figsize=(7,5))

# %%
p1=Pop.iloc[0:16] #提取有效数据
year=p1.index.astype(int) #提取年份，并转换为整数类型

v1=p1["Under 5"].values #提取5岁以下的数据
v2=p1["5 to 19"].values #提取5-19岁的数据
v3=p1["20 to 44"].values #提取20-44岁的数据
v4=p1["45 to 64"].values #提取45-64岁的数据
v5=p1["65+"].values #提取65岁以上的数据

#设置y轴刻度值的一个helper function
def make_yticks(where):
    ytick=[]
    sum=0
    for i in where:
        sum+=i
        ytick.append(sum)
    return ytick

ax.stackplot(year,v1,v2,v3,v4,v5)
ax.set(xlim=(1860,2005),ylim=(0,100),xlabel="Year",ylabel="Population %")
ax1=ax.twinx() #设置双y轴，共享x轴
ax.set_yticks(make_yticks(p1.loc[1860])) #设置第一个y轴刻度值
ax1.set_yticks(make_yticks(p1.loc[2005])) #设置第二个y轴刻度值
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
crime=pd.read_csv("F:/Data/crimeRatesByState2005.csv")
crime2=crime[crime.state !="United States"]
crime2 = crime2[crime.state != "District of Columbia"]
g=sns.jointplot(x='murder',y='burglary',data=crime2,kind="reg",size=5,ration=3,color="g")
plt.show()
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-980cd1424e4a> in <module>()
#       2 crime2=crime[crime.state !="United States"]
#       3 crime2 = crime2[crime.state != "District of Columbia"]
# ----> 4 g=sns.jointplot(x='murder',y='burglary',data=crime2,kind="reg",size=5,ration=3,color="g")
#       5 plt.show()
#
# C:\Users\Administrator\Anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2280
#    2281         marginal_kws.setdefault("color", color)
# -> 2282         grid.plot_marginals(distplot, **marginal_kws)
#    2283
# ...

# %%
crime2=crime[crime.state !="United States"]

# %%
crime
# Out:
#                    state  murder  forcible_rape  robbery  aggravated_assault  \
# 0          United States     5.6           31.7    140.7               291.1
# 1                Alabama     8.2           34.3    141.4               247.8
# 2                 Alaska     4.8           81.1     80.9               465.1
# 3                Arizona     7.5           33.8    144.4               327.4
# 4               Arkansas     6.7           42.9     91.1               386.8
# 5             California     6.9           26.0    176.1               317.3
# 6               Colorado     3.7           43.4     84.6               264.7
# 7            Connecticut     2.9           20.0    113.0               138.6
# 8               Delaware     4.4           44.7    154.8               428.2
# 9   District of Columbia    35.4           30.2    672.1               721.3
# 10               Florida     5.0           37.1    169.4               496.6
# ...

# %%
df=pd.read_excel("F:/Data/图书馆.XLS")

# %%
df1= data_df['读者单位'].str.split('/', expand=True)

# %%
>>> bool = df.str.contains('Mr\.')
>>> filter_data = df[bool]

# %%
df3 = df[df['读者单位'].isin(['1012171/化学工程与工艺（专升本）/材料与化工学院'])]

# %%
df3
# Out:
#           读者证号 读者姓名                          读者单位 借出状态        条形码        正题名  \
# NaN  101217101    李  1012171/化学工程与工艺（专升本）/材料与化工学院   已还  207480769       东北往事
# NaN  101217103    李  1012171/化学工程与工艺（专升本）/材料与化工学院   已还  205532137  化工厂的设计与改造
# NaN  101217103    李  1012171/化学工程与工艺（专升本）/材料与化工学院   未还  205667526   化工原理课程设计
# NaN  101217103    李  1012171/化学工程与工艺（专升本）/材料与化工学院   未还  203897426       化工计算
# NaN  101217107    李  1012171/化学工程与工艺（专升本）/材料与化工学院   已还  210620194       化工原理
# NaN  101217107    李  1012171/化学工程与工艺（专升本）/材料与化工学院   已还  204920452       化工原理
# NaN  101217107    李  1012171/化学工程与工艺（专升本）/材料与化工学院   未还  213007645       化工原理
# NaN  101217107    李  1012171/化学工程与工艺（专升本）/材料与化工学院   已还  213321751   化工原理课程设计
# NaN  101217107    李  1012171/化学工程与工艺（专升本）/材料与化工学院   未还  213320351       化工设计
# NaN  101217107    李  1012171/化学工程与工艺（专升本）/材料与化工学院   已还  212589019      化学工艺学
# NaN  101217107    李  1012171/化学工程与工艺（专升本）/材料与化工学院   未还  213321751   化工原理课程设计
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
crime=pd.read_csv("F:/Data/crimeRatesByState2005.csv")
crime2=crime[crime.state !="United States"]
crime2 = crime2[crime.state != "District of Columbia"]
crime2=crime2.drop(['state'],axis=1)
crime2=crime2.drop(['population'],axis=1)
g=sns.pairplot(crime2)
plt.show()
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()

# %%
import pandas as pd
import numpy as np
crime = pd.read_csv("F:/Data/crimeRatesByState2005.csv")
crime2 = crime[crime.state != "United States"]
crime2 = crime2[crime2.state != "District of Columbia"]
s = list(crime2.population/10000)
colors = np.random.rand(len(list(crime2.murder)))
cm = plt.cm.get_cmap()
plt.scatter(x=list(crime2.murder), y=list(crime2.burglary), s=s, c=colors, cmap=cm, linewidth=0.5, alpha=0.5)
plt.xlabel("murder")
plt.show()
